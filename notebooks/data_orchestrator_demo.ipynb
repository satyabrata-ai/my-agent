# %%
# Imports
from app.sub_agents.data_orchestrator import tools as da
import json
print('tools imported')

# %%
# Discover tables (requires BigQuery credentials)
print(da.discover_bq_tables())

# %%
# Baseline metrics example (will return an error-style dict if BigQuery isn't configured)
print(da.get_baseline_metrics('AAPL'))

# %%
# Event impact example (Earnings)
print(da.compute_event_impact('AAPL', 'Earnings', pre_window_days=1, post_window_days=1))
